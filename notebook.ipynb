# %% [markdown]
# # Utility notebook: Generate audio or video

# %%
import sys
sys.path.append('./utils')
import ai

# %%
# If you make changes in ai.py, reload it like this:
import importlib
import ai

# Reload the module to reflect the changes
importlib.reload(ai)
# Out:
# <module 'ai' from '/Users/wesleydebolster/Git/weslbo/VideoCreator/utils/ai.py'>

# %% [markdown]
# ## Generate audio

# %%
# %%audio
# Hi there! How are your doing today? I hope you're having a great day. I'm here to help you with any questions or tasks you have. Just let me know what you need!
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Info: on_underlying_io_bytes_received: Close frame received
# Info: on_underlying_io_bytes_received: closing underlying io.
# Info: on_underlying_io_close_complete: uws_state: 6.

# %% [markdown]
# ## Generate video

# %%
# %%video
# Hi there! How are your doing today? I hope you're having a great day.
# I'm here to help you with any questions or tasks you have. Just let me know what you need!
# Out:
# Job ID: 8832704f-4570-47c5-8685-fd527bc7d8ba
# - batch avatar job is [Running]
# - batch avatar job is [Running]
# - batch avatar job is [Running]
# Download URL: https://stttssvcprodweu.blob.core.windows.net/batchsynthesis-output/1b2064e3ffa540e090d029a1c66f7f6b/8832704f-4570-47c5-8685-fd527bc7d8ba/0001.mp4?skoid=3549ea4f-af13-49c5-88bf-11df6c717491&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skt=2025-03-23T18%3A26%3A19Z&ske=2025-03-29T18%3A31%3A19Z&sks=b&skv=2023-11-03&sv=2023-11-03&st=2025-03-24T07%3A50%3A13Z&se=2025-03-27T07%3A55%3A13Z&sr=b&sp=rl&sig=3UKcLhAzBgsgHAmjKwvZv0G3i8F4WWf1AqONPirdAUk%3D
# - batch avatar job succeeded
# - Get batch avatar job successfully
# <video src="./video/2025-03-24_08-55u.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
